# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %matplotlib inline

# %%
# !nvidia-smi
# Out:
# Mon Apr  3 17:41:44 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Checking if CUDA is available

# %%
torch.cuda.is_available(), torch.cuda.get_device_name(0), torch.cuda.get_device_properties(0)
# Out:
# (True,
#  'Tesla T4',
#  _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15101MB, multi_processor_count=40))

# %% [markdown]
# ## Clone Ultralytics library into our repository

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15365, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 15365 (delta 0), reused 4 (delta 0), pack-reused 15355
# Receiving objects: 100% (15365/15365), 14.30 MiB | 30.07 MiB/s, done.
# Resolving deltas: 100% (10504/10504), done.

# %% [markdown]
# ## Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# requirements: YOLOv5 requirement "gitpython>=3.1.30" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
img = 'https://ultralytics.com/images/zidane.jpg'
results = model(img)
print(results)
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 239.2ms pre-process, 4349.2ms inference, 49.5ms NMS per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## Model Training

# %%
# !cd yolov5 && python train.py --img 512 --batch 32 --epochs 100 --data dataset.yaml --weights yolov5s.pt
# Out:
# 2023-04-03 18:10:04.947925: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 18:10:05.947586: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %% [markdown]
# ## Model Inferencing

# %%
# !python /content/yolov5/detect.py --weights yolov5/runs/train/exp2/weights/last.pt --img 512 --conf 0.25 --source /content/drive/MyDrive/data/test
# Out:
# detect: weights=['yolov5/runs/train/exp2/weights/last.pt'], source=/content/drive/MyDrive/data/test, data=yolov5/data/coco128.yaml, imgsz=[512, 512], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-133-gcca5e21 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/296 /content/drive/.shortcut-targets-by-id/14AFRbpwHXV4EbUthUThqjzF0Ml6RaVTD/data/test/000383.jpg: 288x512 (no detections), 41.0ms
# image 2/296 /content/drive/.shortcut-targets-by-id/14AFRbpwHXV4EbUthUThqjzF0Ml6RaVTD/data/test/000385.jpg: 320x512 (no detections), 42.1ms
# ...
